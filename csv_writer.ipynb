# %%
# prompt: from above model save csv file with time stamp and action

from ultralytics import YOLO
import cv2
import csv
from datetime import datetime, timedelta

# ... (rest of the code from the preceding code) ...

# Load the YOLO model
model = YOLO('/yolov9c_mouse-bahavior-v1_001.pt')

# Path to the video file
video_path = '/video_eating.mp4'

# Path to the output CSV file
csv_path = '/content/action_detection_results.csv'

# Open the video file
cap = cv2.VideoCapture(video_path)

# Get video properties
fps = cap.get(cv2.CAP_PROP_FPS)
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
duration = frame_count / fps

# Define CSV header
csv_header = ['Timestamp', 'Frame Number', 'Mouse ID', 'Action']

# Create the CSV file and write the header
with open(csv_path, 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    csv_writer.writerow(csv_header)

# Initialize frame number and start time
frame_number = 0
start_time = datetime.now()

# Loop through video frames
while cap.isOpened():
    success, frame = cap.read()
    if not success:
        break

    # Run YOLO inference on the frame
    results = model(frame)

    # Process results
    for r in results:
        boxes = r.boxes
        for box in boxes:
            cls = int(box.cls[0])
            conf = float(box.conf[0])

            # Map class ID to action
            action_map = {0: 'drinking', 1: 'eating', 2: 'moving'}
            action = action_map.get(cls, 'unknown')

            # Calculate timestamp
            elapsed_time = frame_number / fps
            timestamp = start_time + timedelta(seconds=elapsed_time)

            # Assuming one mouse per frame
            mouse_id = 1

            # Append data to the CSV file
            with open(csv_path, 'a', newline='') as csvfile:
                csv_writer = csv.writer(csvfile)
                csv_writer.writerow([timestamp.strftime('%Y-%m-%d %H:%M:%S.%f')[:-3],
                                     frame_number,
                                     mouse_id,
                                     action])

    frame_number += 1

    # Print progress
    if frame_number % 100 == 0:
        print(f"Processed {frame_number} frames")

# Release the video capture object
cap.release()

# Print confirmation message
print(f"CSV file saved at: {csv_path}")
# Out:
# 0: 512x640 1 eating, 236.8ms
# Speed: 3.4ms preprocess, 236.8ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 drinking, 225.9ms
# Speed: 2.0ms preprocess, 225.9ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 213.0ms
# Speed: 1.9ms preprocess, 213.0ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 215.3ms
# Speed: 1.8ms preprocess, 215.3ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 210.6ms
# Speed: 1.9ms preprocess, 210.6ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 220.9ms
# Speed: 2.0ms preprocess, 220.9ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 231.1ms
# Speed: 2.1ms preprocess, 231.1ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 218.4ms
# Speed: 2.1ms preprocess, 218.4ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 216.2ms
# Speed: 1.9ms preprocess, 216.2ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 222.0ms
# Speed: 1.9ms preprocess, 222.0ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 228.5ms
# Speed: 2.1ms preprocess, 228.5ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 225.7ms
# Speed: 2.1ms preprocess, 225.7ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 222.5ms
# Speed: 2.2ms preprocess, 222.5ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 217.0ms
# Speed: 1.8ms preprocess, 217.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 225.3ms
# Speed: 2.0ms preprocess, 225.3ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 229.5ms
# Speed: 2.0ms preprocess, 229.5ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 224.8ms
# Speed: 2.0ms preprocess, 224.8ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 218.4ms
# Speed: 2.0ms preprocess, 218.4ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 221.2ms
# Speed: 1.9ms preprocess, 221.2ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 228.1ms
# Speed: 1.8ms preprocess, 228.1ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 212.1ms
# Speed: 2.2ms preprocess, 212.1ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 208.6ms
# Speed: 2.1ms preprocess, 208.6ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 214.7ms
# Speed: 2.0ms preprocess, 214.7ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 216.4ms
# Speed: 2.1ms preprocess, 216.4ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 213.3ms
# Speed: 2.2ms preprocess, 213.3ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 211.8ms
# Speed: 1.9ms preprocess, 211.8ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 209.6ms
# Speed: 2.1ms preprocess, 209.6ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 214.5ms
# Speed: 1.9ms preprocess, 214.5ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 221.3ms
# Speed: 2.0ms preprocess, 221.3ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 219.9ms
# Speed: 2.2ms preprocess, 219.9ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 210.2ms
# Speed: 2.0ms preprocess, 210.2ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 214.2ms
# Speed: 1.9ms preprocess, 214.2ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 217.2ms
# Speed: 2.0ms preprocess, 217.2ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 212.2ms
# Speed: 2.2ms preprocess, 212.2ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 211.2ms
# Speed: 2.1ms preprocess, 211.2ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 eatings, 208.3ms
# Speed: 2.1ms preprocess, 208.3ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 218.2ms
# Speed: 1.9ms preprocess, 218.2ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 eatings, 221.1ms
# Speed: 1.9ms preprocess, 221.1ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 eatings, 209.2ms
# Speed: 2.1ms preprocess, 209.2ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 212.3ms
# Speed: 2.0ms preprocess, 212.3ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 235.7ms
# Speed: 2.2ms preprocess, 235.7ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 eatings, 233.0ms
# Speed: 2.2ms preprocess, 233.0ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 230.9ms
# Speed: 2.1ms preprocess, 230.9ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 240.6ms
# Speed: 2.0ms preprocess, 240.6ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 242.3ms
# Speed: 1.9ms preprocess, 242.3ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 237.5ms
# Speed: 2.2ms preprocess, 237.5ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 242.2ms
# Speed: 2.2ms preprocess, 242.2ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 240.4ms
# Speed: 2.2ms preprocess, 240.4ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 228.9ms
# Speed: 2.1ms preprocess, 228.9ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 229.6ms
# Speed: 2.2ms preprocess, 229.6ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 232.5ms
# Speed: 2.2ms preprocess, 232.5ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 232.5ms
# Speed: 2.1ms preprocess, 232.5ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 232.4ms
# Speed: 2.0ms preprocess, 232.4ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 210.7ms
# Speed: 2.1ms preprocess, 210.7ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 211.1ms
# Speed: 2.2ms preprocess, 211.1ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 213.3ms
# Speed: 2.0ms preprocess, 213.3ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 209.0ms
# Speed: 2.1ms preprocess, 209.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 226.8ms
# Speed: 1.9ms preprocess, 226.8ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 216.5ms
# Speed: 2.2ms preprocess, 216.5ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 208.4ms
# Speed: 2.0ms preprocess, 208.4ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 212.4ms
# Speed: 2.0ms preprocess, 212.4ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 225.1ms
# Speed: 2.0ms preprocess, 225.1ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 221.0ms
# Speed: 2.1ms preprocess, 221.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 211.6ms
# Speed: 2.0ms preprocess, 211.6ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 213.5ms
# Speed: 2.2ms preprocess, 213.5ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 210.7ms
# Speed: 2.0ms preprocess, 210.7ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 229.0ms
# Speed: 1.9ms preprocess, 229.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 211.8ms
# Speed: 1.9ms preprocess, 211.8ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 212.0ms
# Speed: 1.9ms preprocess, 212.0ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 214.9ms
# Speed: 1.9ms preprocess, 214.9ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 drinking, 225.0ms
# Speed: 2.0ms preprocess, 225.0ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 drinkings, 237.3ms
# Speed: 2.3ms preprocess, 237.3ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 drinking, 237.3ms
# Speed: 2.2ms preprocess, 237.3ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 drinking, 234.2ms
# Speed: 2.2ms preprocess, 234.2ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 225.7ms
# Speed: 2.2ms preprocess, 225.7ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 221.4ms
# Speed: 2.1ms preprocess, 221.4ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 212.1ms
# Speed: 2.0ms preprocess, 212.1ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 214.0ms
# Speed: 2.1ms preprocess, 214.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 212.3ms
# Speed: 2.0ms preprocess, 212.3ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 227.9ms
# Speed: 2.0ms preprocess, 227.9ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 214.5ms
# Speed: 1.9ms preprocess, 214.5ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 216.8ms
# Speed: 1.8ms preprocess, 216.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 211.0ms
# Speed: 1.9ms preprocess, 211.0ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 eating, 223.1ms
# Speed: 2.0ms preprocess, 223.1ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 drinking, 221.1ms
# Speed: 2.3ms preprocess, 221.1ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 2 drinkings, 212.8ms
# Speed: 1.8ms preprocess, 212.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 drinking, 212.7ms
# Speed: 1.9ms preprocess, 212.7ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 drinking, 215.2ms
# Speed: 2.1ms preprocess, 215.2ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 drinking, 229.5ms
# Speed: 2.3ms preprocess, 229.5ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 212.2ms
# Speed: 2.1ms preprocess, 212.2ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 210.1ms
# Speed: 1.8ms preprocess, 210.1ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 (no detections), 220.2ms
# Speed: 2.1ms preprocess, 220.2ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 drinking, 236.5ms
# Speed: 2.0ms preprocess, 236.5ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 drinking, 238.0ms
# Speed: 2.1ms preprocess, 238.0ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 drinking, 240.8ms
# Speed: 2.1ms preprocess, 240.8ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 640)
# CSV file saved at: /content/action_detection_results.csv
